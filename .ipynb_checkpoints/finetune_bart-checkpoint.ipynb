# %%
from datasets import load_dataset
from transformers import BartTokenizer, BartForConditionalGeneration, Trainer, TrainingArguments
from sklearn.metrics import accuracy_score
from transformers import BartTokenizer, BartForConditionalGeneration

model_name = "facebook/bart-base"  # or "facebook/bart-large"

tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)

# dataset = load_dataset("csv", data_files="/Users/eddie/Downloads/VLMTrain/MViTv2_Train.csv")
dataset = load_dataset("csv", data_files="/Users/eddie/Downloads/VLMTrain/MViTv2_Train_Recognition_Full.csv")
test_dataset = load_dataset("csv", data_files="/Users/eddie/Downloads/VLMTrain/MViTv2_Test_Recognition_Full.csv")

# %%
def preprocess_data(examples):
    q = "What is the next action?"
    inputs = [f"Question: {q} Context: {c}" for c in zip(examples["context"])]
    targets = examples["answer"]
    model_inputs = tokenizer(inputs, padding="max_length", truncation=True, max_length=512)
    labels = tokenizer(targets, padding="max_length", truncation=True, max_length=25)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

dataset = dataset.map(preprocess_data, batched=True)
test_dataset = test_dataset.map(preprocess_data, batched = True)
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'context', 'answer', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 7429
#     })
# })

# %%
num_epochs = 1 
from transformers import TrainingArguments, Trainer
for i in range(num_epochs):

    training_args = TrainingArguments(
        output_dir="./bart_qa",
        evaluation_strategy="epoch",
        save_strategy="no",
        per_device_train_batch_size=8,
        per_device_eval_batch_size=8,
        num_train_epochs=30,
        weight_decay=0.01,
        logging_dir="./logs",
    )

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=dataset["train"],
        eval_dataset = test_dataset["train"],
        # predict_with_generate = True,
        # preprocess_logits_for_metrics=preprocess_logits_for_metrics
        # compute_loss_func=compute_loss_func
    )

    trainer.train()
# Out:
# c:\Users\eddie\anaconda3\envs\LLM\lib\site-packages\transformers\training_args.py:1611: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: eddie-r-zhang (eddie-r-zhang-n-a) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\eddie\Trauma_THOMPSON\Trauma_THOMPSON\VideoSwin\new architecture\wandb\run-20250405_221216-bt6kdhmu</code>
# Syncing run <strong><a href='https://wandb.ai/eddie-r-zhang-n-a/huggingface/runs/bt6kdhmu' target="_blank">./bart_qa</a></strong> to <a href='https://wandb.ai/eddie-r-zhang-n-a/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/eddie-r-zhang-n-a/huggingface' target="_blank">https://wandb.ai/eddie-r-zhang-n-a/huggingface</a>
#  View run at <a href='https://wandb.ai/eddie-r-zhang-n-a/huggingface/runs/bt6kdhmu' target="_blank">https://wandb.ai/eddie-r-zhang-n-a/huggingface/runs/bt6kdhmu</a>
#     <div>
#
#       <progress value='2787' max='2787' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2787/2787 04:53, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.595300</td>
#       <td>0.086741</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.040900</td>
#       <td>0.082448</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.029500</td>
#       <td>0.084194</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
model.save_pretrained("./bart_full", from_pt=True) 
tokenizer.save_pretrained("./bart_full")
# Out:
# c:\Users\eddie\anaconda3\envs\LLM\lib\site-packages\transformers\modeling_utils.py:3353: UserWarning: Moving the following attributes in the config to the generation config: {'early_stopping': True, 'num_beams': 4, 'no_repeat_ngram_size': 3, 'forced_bos_token_id': 0}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# ('./bart_full\\tokenizer_config.json',
#  './bart_full\\special_tokens_map.json',
#  './bart_full\\vocab.json',
#  './bart_full\\merges.txt',
#  './bart_full\\added_tokens.json')

# %%
# from transformers import EncoderDecoderModel, BertTokenizer

# # Load trained model and tokenizer
model_name = "./bart_full"  # Change to your actual model path
tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name).to("cuda")

# Ensure correct config

def generate_answer(question, context):
    # Format input as: "question: ... context: ..."
    input_text = f"question: {question}  context: {context}"

    # Tokenize input
    inputs = tokenizer(input_text, return_tensors="pt", truncation=True, max_length=512).to("cuda")

    # Generate response
    output_ids = model.generate(inputs.input_ids, max_length=100, num_beams=5)

    # Decode output tokens
    answer = tokenizer.decode(output_ids[0], skip_special_tokens=True)
    return answer

# print(generate_answer("What is the next action?", "palpate landmark, take swab, prep site"))

# %%
test_dataset = load_dataset("csv", data_files="/Users/eddie/Downloads/VLMTrain/MViTv2_Test_Recognition_Full.csv")
test_dataset = test_dataset["train"]
# questions = test_dataset["question"]
context = test_dataset["context"]
labels = test_dataset["answer"]    
print(test_dataset)
print(labels)
print(context)
# Out:
# Dataset({
#     features: ['question', 'context', 'answer'],
#     num_rows: 683
# })
# ['palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'insert finger', 'incise membrane', 'drop scalpel', 'take hook', 'remove finger', 'insert hook', 'take tube', 'insert tube', 'remove hook', 'drop hook', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'palpate landmark', 'inject lidocaine', 'drop syringe', 'take scalpel', 'palpate landmark', 'incise skin', 'incise skin', 'insert finger', 'remove finger', 'incise membrane', 'insert finger', 'drop scalpel', 'take hook', 'remove finger', 'insert hook', 'take tube', 'insert tube', 'remove hook', 'drop hook', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'incise skin', 'insert finger', 'remove finger', 'incise membrane', 'insert finger', 'drop scalpel', 'take hook', 'remove finger', 'insert hook', 'take tube', 'insert tube', 'remove hook', 'drop hook', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'insert finger', 'incise membrane', 'drop scalpel', 'take bougie', 'insert bougie', 'remove finger', 'take tube', 'attach tube', 'insert tube', 'remove bougie', 'drop bougie', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'insert finger', 'incise membrane', 'drop scalpel', 'take bougie', 'insert bougie', 'remove finger', 'take tube', 'attach tube', 'insert tube', 'inflate cuff', 'detach syringe', 'drop syringe', 'remove bougie', 'drop bougie', 'palpate landmark', 'take swab', 'prep site', 'prep site', 'drop swab', 'take syringe', 'take lidocaine', 'withdraw lidocaine', 'drop lidocaine', 'inject lidocaine', 'inject lidocaine', 'drop syringe', 'take glove', 'don glove', 'take glove', 'don glove', 'take scalpel', 'palpate landmark', 'incise skin', 'incise skin', 'incise skin', 'drop scalpel', 'take hook', 'take tube', 'insert hook', 'insert tube', 'remove tube', 'remove hook', 'drop hook', 'drop tube', 'insert finger', 'sweep finger', 'remove finger', 'take hook', 'take tube', 'insert hook', 'insert tube', 'remove hook', 'drop hook', 'take syringe', 'attach syringe', 'inflate cuff', 'detach syringe', 'attach syringe', 'inflate cuff', 'detach syringe', 'drop syringe', 'remove obturator', 'drop obturator', 'take ambubag', 'attach ambubag', 'compress ambubag', 'compress ambubag', 'compress ambubag', 'detach ambubag', 'drop ambubag', 'take tape', 'thread tape', 'thread tape', 'tie tape', 'secure tube', 'tie tape', 'palpate landmark', 'incise skin', 'incise skin', 'drop scalpel', 'take scalpel', 'incise membrane', 'drop scalpel', 'take tube', 'insert tube', 'insert tube', 'remove obturator', 'drop obturator', 'palpate landmark', 'take scalpel', 'incise skin', 'drop scalpel', 'take kelly', 'palpate landmark', 'insert kelly', 'expand kelly', 'remove kelly', 'take tube', 'attach kelly and tube', 'insert finger', 'remove finger', 'insert kelly/tube', 'detach kelly', 'remove kelly', 'drop kelly', 'take clamp', 'open clamp', 'apply clamp', 'close clamp', 'palpate landmark', 'take scalpel', 'incise skin', 'drop scalpel', 'palpate landmark', 'take scalpel', 'incise skin', 'drop scalpel', 'take kelly', 'insert kelly', 'expand kelly', 'remove kelly', 'insert finger', 'sweep finger', 'take tube', 'insert tube', 'advance tube', 'remove finger', 'take clamp', 'open clamp', 'apply clamp', 'close clamp', 'palpate landmark', 'take scalpel', 'incise skin', 'drop scalpel', 'take kelly', 'palpate landmark', 'insert kelly', 'expand kelly', 'remove kelly', 'drop kelly', 'insert finger', 'sweep finger', 'take kelly', 'take ...
# ['palpate landmark', 'palpate landmark. take swab', 'palpate landmark. take swab. prep site', 'palpate landmark. take swab. prep site. drop swab', 'palpate landmark. take swab. prep site. drop swab. take syringe', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel. take hook', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel. take hook. insert hook', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel. take hook. insert hook. insert hook', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel. take hook. insert hook. insert hook. take tube', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel. take hook. insert hook. insert hook. take tube. insert tube', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel. take hook. insert hook. insert hook. take tube. insert tube. remove hook', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel. take hook. insert hook. insert hook. take tube. insert tube. remove hook. drop hook', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel. take hook. insert hook. insert hook. take tube. insert tube. remove hook. drop hook. detach syringe', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel. take hook. insert hook. insert hook. take tube. insert tube. remove hook. drop hook. detach syringe. drop syringe', 'palpate landmark. take swab. prep site. drop swab. take syringe. inject lidocaine. drop swab. take scalpel. incise skin. insert finger. incise membrane. drop scalpel. take hook. insert hook. insert hook. take tube. insert tube. remove hook. drop hook. detach syringe. drop syringe. drop syringe', 'drop swab', 'drop swab. take swab', 'drop swab. take swab. prep site', 'drop swab. take swab. prep site. drop swab', 'drop swab. take swab. prep site. drop swab. drop syringe', 'drop swab. take swab. prep site. drop swab. drop syringe. take syringe', 'drop swab. take swab. prep site. drop swab. drop syringe. take syringe. inject lidocaine', 'drop swab. take swab. prep site. drop swab. drop syringe. take syringe. inject lidocaine. drop syringe', 'drop swab. take swab. prep site. drop swab. drop syringe. take syringe. inject lidoc ...

# %%
generated_answers = []
for i in range(len(context)):
    # print(questions[i], context[i])
    generated_answers.append(generate_answer("What is the next action?", context[i]))
    print(generated_answers[i], labels[i])
print(generated_answers)
print(labels)
# Out:
# palpate landmark palpate landmark
# take swab take swab
# prep site prep site
# drop swab drop swab
# take syringe take syringe
# inject lidocaine inject lidocaine
# drop syringe drop syringe
# take scalpel take scalpel
# incise skin incise skin
# insert finger insert finger
# incise membrane incise membrane
# drop scalpel drop scalpel
# take hook take hook
# insert hook remove finger
# insert hook insert hook
# take tube take tube
# insert tube insert tube
# remove hook remove hook
# drop hook drop hook
# detach syringe inflate cuff
# drop syringe detach syringe
# drop syringe drop syringe
# drop swab palpate landmark
# take swab take swab
# prep site prep site
# drop swab drop swab
# take syringe take syringe
# take syringe palpate landmark
# inject lidocaine inject lidocaine
# drop syringe drop syringe
# take scalpel take scalpel
# take scalpel palpate landmark
# incise skin incise skin
# incise skin incise skin
# insert finger insert finger
# insert finger remove finger
# incise skin incise membrane
# incise membrane insert finger
# drop scalpel drop scalpel
# take hook take hook
# insert hook remove finger
# insert hook insert hook
# take tube take tube
# insert tube insert tube
# remove hook remove hook
# drop hook drop hook
# inflate cuff inflate cuff
# detach syringe detach syringe
# drop syringe drop syringe
# palpate landmark palpate landmark
# take swab take swab
# prep site prep site
# drop swab drop swab
# take syringe take syringe
# inject lidocaine inject lidocaine
# drop syringe drop syringe
# take scalpel take scalpel
# incise skin incise skin
# incise skin incise skin
# incise membrane insert finger
# insert finger remove finger
# incise membrane incise membrane
# incise membrane insert finger
# drop scalpel drop scalpel
# take hook take hook
# insert hook remove finger
# insert hook insert hook
# take tube take tube
# remove hook insert tube
# remove hook remove hook
# drop hook drop hook
# inflate cuff inflate cuff
# detach syringe detach syringe
# drop syringe drop syringe
# palpate landmark palpate landmark
# take swab take swab
# prep site prep site
# drop swab drop swab
# take syringe take syringe
# inject lidocaine inject lidocaine
# drop syringe drop syringe
# take scalpel take scalpel
# incise skin incise skin
# insert finger insert finger
# incise membrane incise membrane
# drop scalpel drop scalpel
# take bougie take bougie
# insert bougie insert bougie
# remove finger remove finger
# take tube take tube
# attach tube attach tube
# insert tube insert tube
# remove bougie remove bougie
# drop bougie drop bougie
# inflate cuff inflate cuff
# detach syringe detach syringe
# drop syringe drop syringe
# palpate landmark palpate landmark
# take swab take swab
# prep site prep site
# drop swab drop swab
# take syringe take syringe
# inject lidocaine inject lidocaine
# drop syringe drop syringe
# take scalpel take scalpel
# incise skin incise skin
# insert finger insert finger
# incise membrane incise membrane
# drop scalpel drop scalpel
# take bougie take bougie
# insert bougie insert bougie
# remove finger remove finger
# take tube take tube
# attach tube attach tube
# insert tube insert tube
# insert tube inflate cuff
# detach syringe detach syringe
# drop syringe drop syringe
# remove bougie remove bougie
# drop bougie drop bougie
# palpate landmark palpate landmark
# take swab take swab
# prep site prep site
# prep site prep site
# drop swab drop swab
# take syringe take syringe
# inject lidocaine take lidocaine
# inject lidocaine withdraw lidocaine
# drop lidocaine drop lidocaine
# inject lidocaine inject lidocaine
# inject lidocaine inject lidocaine
# take bougie drop syringe
# take glove take glove
# don glove don glove
# take glove take glove
# don glove don glove
# take scalpel take scalpel
# incise skin palpate landmark
# incise skin incise skin
# incise skin incise skin
# incise skin incise skin
# drop syringe drop scalpel
# take hook take hook
# take tape take tube
# insert hook insert hook
# insert hook insert tube
# remove case remove tube
# remove hook remove hook
# drop syringe drop hook
# drop syringe drop tube
# insert hook insert finger
# insert hook sweep finger
# drop ambubag remove finger
# drop syringe take hook
# drop obturator take tube
# insert hook insert hook
# insert hook insert tube
# remove hook remove hook
# drop syringe drop hook
# attach syringe take syringe
# attach syringe attach syringe
# attach syringe inflate cuff
# attach syringe detach syringe
# attach syringe attach syringe
# attach syringe inflate cuff
# attach syringe detach syringe
# drop obturator drop syringe
# drop obturator remove obturator
# drop syringe drop obturator
# take ambubag take ambubag
# detach ambubag attach ambubag
# palpate landmark compress ambubag
# flush catheter compress ambubag
# incise skin compress ambubag
# drop ambubag detach ambubag
# drop ambubag drop ambubag
# take tube take tape
# thread tape thread tape
# thread tape thread tape
# tie tape tie tape
# tie tape secure tube
# tie tape tie tape
# drop scalpel palpate landmark
# incise skin incise skin
# incise skin incise skin
# drop scalpel drop scalpel
# take scalpel take scalpel
# incise membrane incise membrane
# identify landmark drop scalpel
# take tube take tube
# take tube insert tube
# insert tube insert tube
# insert tube remove obturator
# drop obturator drop obturator
# palpate landmark palpate landmark
# take scalpel take scalpel
# incise skin incise skin
# take tube drop scalpel
# take kelly take kelly
# remove kelly palpate landmark
# expand kelly insert kelly
# remove kelly expand kelly
# palpate landmark remove kelly
# take tube take tube
# insert tube attach kelly and tube
# insert finger insert finger
# remove kelly remove finger
# expand kelly insert kelly/tube
# remove kelly detach kelly
# insert finger remove kelly
# advance tube drop kelly
# take clamp take clamp
# open clamp open clamp
# apply clamp apply clamp
# close clamp close clamp
# palpate landmark palpate landmark
# incise skin take scalpel
# incise skin incise skin
# incise skin drop scalpel
# insert kelly palpate landmark
# take scalpel take scalpel
# incise skin incise skin
# take kelly drop scalpel
# take kelly take kelly
# insert kelly insert kelly
# insert kelly expand kelly
# remove kelly remove kelly
# sweep finger insert finger
# sweep finger sweep finger
# take tube take tube
# insert tube insert tube
# insert tube advance tube
# advance tube remove finger
# take clamp take clamp
# take clamp open clamp
# apply clamp apply clamp
# close clamp close clamp
# palpate landmark palpate landmark
# take scalpel take scalpel
# incise skin incise skin
# drop scalpel drop scalpel
# take kelly take kelly
# drop kelly palpate landmark
# insert kelly insert kelly
# remove kelly expand kelly
# take kelly remove kelly
# drop kelly drop kelly
# drop kelly insert finger
# insert finger sweep finger
# drop kelly take kelly
# take kelly take tube
# remove kelly attach kelly and tube
# remove kelly insert finger
# insert finger insert kelly/tube
# remove kelly remove finger
# remove kelly detach kelly
# advance tube remove kelly
# advance tube advance tube
# take clamp drop kelly
# take clamp take clamp
# open clamp open clamp
# apply clamp apply clamp
# close clamp close clamp
# palpate landmark palpate landmark
# take scalpel take scalpel
# incise skin incise skin
# take scalpel drop scalpel
# take kelly take kelly
# insert kelly insert kelly
# detach kelly expand kelly
# remove kelly remove kelly
# take kelly drop kelly
# insert finger insert finger
# sweep finger sweep finger
# drop scalpel remove finger
# take tube take tube
# take kelly take kelly
# remove kelly attach kelly and tube
# insert finger insert finger
# insert finger insert kelly/tube
# remove kelly detach kelly
# advance tube remove kelly
# advance tube advance tube
# advance tube remove finger
# take clamp drop kelly
# take clamp take clamp
# take clamp open clamp
# apply clamp apply clamp
# close clamp close clamp
# take swab take swab
# prep site prep site
# prep site prep site
# take lidocaine drop swab
# take glove take glove
# don glove don glove
# take glove take glove
# don glove don glove
# take scalpel take syringe
# withdraw lidocaine take lidocaine
# withdraw lidocaine withdraw lidocaine
# drop lidocaine drop lidocaine
# palpate landmark palpate landmark
# inject lidocaine inject lidocaine
# drop kelly drop syringe
# take scalpel take scalpel
# take scalpel palpate landmark
# incise skin incise skin
# drop kelly drop scalpel
# drop kelly take kelly
# remove finger insert kelly
# remove finger expand kelly
# remove kelly expand kelly
# expand kelly insert kelly
# expand kelly expand kelly
# take kelly remove kelly
# take scalpel drop kelly
# take tube take kelly
# advance tube insert kelly
# insert finger remove kelly
# palpate landmark insert finger
# remove kelly insert kelly
# palpate landmark remove finger
# drop kelly expand kelly
# remove finger expand kelly
# insert kelly expand kelly
# take kelly remove kelly
# palpate landmark insert finger
# palpate landmark sweep finger
# sweep finger remove finger
# insert finger take kelly
# take tube take tube
# insert tube attach kelly and tube
# remove finger insert finger
# insert finger insert kelly/tube
# incise tape detach kelly
# detach kelly advance tube
# remove kelly remove kelly
# advance tube advance tube
# take tube drop kelly
# take scalpel take heimlich
# take scalpel attach heimlich
# take tape take tape
# take tape tear strip
# take tape drop tape
# attach strip attach strip
# take tape take tape
# take tape tear strip
# attach strip attach strip
# take stethoscope take stethoscope
# auscultate lungs auscultate lungs
# identify landmark identify landmark
# take scalpel take scalpel
# identify landmark identify landmark
# incise skin incise skin
# take windlass drop scalpel
# identify landmark take kelly
# identify landmark insert kelly
# insert kelly expand kelly
# insert finger remove kelly
# remove finger insert finger
# twist windlass sweep finger
# take kelly remove finger
# take kelly take tube
# insert kelly attach kelly and tube
# insert finger insert finger
# drop kelly insert kelly/tube
# insert kelly advance tube
# remove kelly remove tube
# identify landmark insert finger
# remove kelly sweep finger
# remove finger insert kelly/tube
# advance tube advance tube
# remove kelly detach kelly
# remove kelly remove kelly
# insert catheter advance tube
# palpate landmark identify landmark
# take scalpel take scalpel
# incise skin incise skin
# drop scalpel drop scalpel
# take kelly take kelly
# insert kelly insert kelly
# insert kelly expand kelly
# remove kelly remove kelly
# insert kelly insert kelly
# remove kelly expand kelly
# remove kelly remove kelly
# insert finger drop kelly
# sweep finger insert finger
# remove finger sweep finger
# remove kelly remove finger
# take kelly take kelly
# insert kelly insert kelly
# remove finger expand kelly
# remove kelly remove kelly
# remove kelly drop kelly
# sweep finger insert finger
# drop kelly sweep finger
# insert kelly remove finger
# take tube take kelly
# take tube take tube
# remove finger attach kelly and tube
# remove finger insert kelly/tube
# remove kelly detach kelly
# insert kelly advance tube
# remove kelly remove kelly
# remove kelly drop kelly
# remove kelly advance tube
# take wipe take wipe
# open wipe open wipe
# prep site prep site
# drop wipe drop wipe
# take syringe take syringe
# take catheter take catheter
# attach catheter attach catheter
# prime catheter prime catheter
# drop catheter drop catheter/syringe
# take driver take driver
# take needle take needle
# attach needle attach needle
# palpate landmark palpate landmark
# position needle position needle
# engage driver engage driver
# detach driver detach driver
# drop driver drop driver
# remove stylet remove stylet
# drop stylet drop stylet
# take catheter take catheter
# attach catheter attach catheter
# flush catheter take syringe
# flush catheter flush catheter
# take wipe take wipe
# open wipe open wipe
# prep site prep site
# drop wipe drop wipe
# take driver take driver
# take needle take needle
# attach needle attach needle
# take scalpel palpate landmark
# position needle position needle
# engage driver engage driver
# detach driver detach driver
# drop driver drop driver
# remove stylet remove stylet
# remove stylet drop stylet
# drop stylet take syringe
# take catheter take catheter
# attach catheter attach catheter
# prime catheter prime catheter
# attach catheter attach catheter
# flush catheter take syringe
# flush catheter flush catheter
# flush catheter drop catheter
# take wipe take wipe
# open wipe open wipe
# prep site prep site
# drop wipe drop wipe
# take syringe take syringe
# take syringe take catheter
# attach catheter attach catheter
# prime catheter prime catheter
# take driver drop catheter/syringe
# take driver take driver
# take needle take needle
# attach needle attach needle
# position needle position needle
# position needle engage driver
# position needle detach driver
# drop driver drop driver
# drop stylet remove stylet
# drop stylet drop stylet
# prime catheter take catheter
# attach catheter attach catheter
# flush catheter take syringe
# flush catheter flush catheter
# take wipe take wipe
# take wipe open wipe
# prep site prep site
# drop wipe drop wipe
# take driver take driver
# take needle take needle
# attach needle attach needle
# position needle position needle
# engage driver engage driver
# detach driver detach driver
# drop driver drop driver
# remove stylet remove stylet
# drop stylet drop stylet
# take syringe take syringe
# take catheter take catheter
# attach catheter attach catheter
# prime catheter prime catheter
# attach catheter attach catheter
# flush catheter take syringe
# flush catheter flush catheter
# drop catheter/syringe drop catheter/syringe
# identify landmark identify landmark
# take swab take swab
# prep site prep site
# prep site prep site
# drop syringe drop swab
# take glove take glove
# don glove don glove
# don glove take glove
# don glove don glove
# attach needle take needle
# remove cap remove cap
# attach needle take driver
# attach needle attach needle
# position needle palpate landmark
# position needle position needle
# engage driver engage driver
# detach driver detach driver
# drop driver drop driver
# take driver remove stylet
# take driver drop stylet
# remove cap take catheter
# drop driver attach catheter
# detach syringe take syringe
# attach catheter attach syringe
# flush catheter flush catheter
# take catheter palpate landmark
# engage driver position needle
# engage driver engage driver
# detach driver detach driver
# remove stylet remove stylet
# take catheter take catheter
# remove case attach catheter
# evaluate lungs evaluate lungs
# identify landmark identify landmark
# take swab take swab
# prep site prep site
# take needle drop swab
# take needle take needle
# remove case remove case
# drop case drop case
# attach tape position catheter
# insert catheter insert catheter
# remove needle remove needle
# evaluate lungs drop needle
# evaluate lungs evaluate lungs
# take tape take tape
# tear strip tear strip
# drop tape drop tape
# attach tape attach tape
# evaluate lungs evaluate lungs
# identify landmark identify landmark
# take swab take swab
# prep site prep site
# drop swab drop swab
# take needle take needle
# remove case remove case
# drop case drop case
# position catheter position catheter
# insert catheter insert catheter
# remove needle remove needle
# drop needle drop needle
# evaluate lungs evaluate lungs
# take tape take tape
# tear strip tear strip
# drop tape drop tape
# attach tape attach tape
# evaluate lungs evaluate lungs
# drop swab identify landmark
# prep site take needle
# drop swab remove case
# position catheter drop case
# position catheter position catheter
# insert catheter insert catheter
# remove needle remove needle
# drop needle drop needle
# take tape take tape
# tear strip tear strip
# drop tape drop tape
# drop tape attach tape
# evaluate lungs evaluate lungs
# identify landmark identify landmark
# take swab take swab
# prep site prep site
# drop swab drop swab
# take needle take needle
# drop case remove case
# drop case drop case
# position catheter position catheter
# insert catheter insert catheter
# remove needle remove needle
# insert catheter insert catheter
# drop needle drop needle
# identify landmark identify landmark
# take swab take swab
# prep site prep site
# drop swab drop swab
# take needle take needle
# remove case remove case
# drop case drop case
# position catheter position catheter
# insert catheter insert catheter
# remove needle remove needle
# insert catheter insert catheter
# drop syringe drop needle
# identify landmark take needle
# remove case remove case
# drop case drop case
# identify landmark identify landmark
# position catheter position catheter
# insert catheter insert catheter
# remove needle remove needle
# remove needle drop needle
# identify landmark identify landmark
# identify landmark remove case
# position catheter position catheter
# engage driver insert catheter
# hold driver remove needle
# identify landmark take needle
# identify landmark identify landmark
# remove case remove case
# drop case position catheter
# drop case remove case
# position catheter position catheter
# insert catheter insert catheter
# position catheter remove needle
# identify wound identify wound
# identify wound identify wound
# take tourniquet take tourniquet
# position tourniquet position tourniquet
# tighten strap tighten strap
# take windlass take windlass
# twist windlass twist windlass
# fasten windlass fasten windlass
# verify hemostasis verify hemostasis
# verify hemostasis verify hemostasis
# take tourniquet take tourniquet
# identify wound identify wound
# position tourniquet position tourniquet
# position tourniquet take windlass
# tighten strap tighten strap
# twist windlass twist windlass
# fasten windlass fasten windlass
# verify hemostasis verify hemostasis
# take tourniquet identify wound
# position tourniquet position tourniquet
# position tourniquet tighten strap
# take windlass take windlass
# twist windlass twist windlass
# take windlass fasten windlass
# identify wound verify hemostasis
# identify wound identify wound
# position tourniquet take tourniquet
# position tourniquet position tourniquet
# take windlass take windlass
# tighten strap tighten strap
# fasten windlass take windlass
# twist windlass twist windlass
# fasten windlass fasten windlass
# verify hemostasis verify hemostasis
# take tourniquet take tourniquet
# position tourniquet position tourniquet
# take windlass take windlass
# tighten strap tighten strap
# take windlass take windlass
# twist windlass twist windlass
# fasten windlass fasten windlass
# verify hemostasis verify hemostasis
# identify wound identify wound
# take tourniquet take tourniquet
# position tourniquet position tourniquet
# take strap take strap
# tighten strap tighten strap
# take windlass take windlass
# twist windlass twist windlass
# twist windlass fasten windlass
# position catheter verify hemostasis
# position tourniquet position tourniquet
# tighten strap tighten strap
# take windlass take windlass
# twist windlass twist windlass
# fasten windlass fasten windlass
# position tourniquet take tourniquet
# position tourniquet position tourniquet
# position tourniquet tighten strap
# take windlass take windlass
# twist windlass twist windlass
# take windlass fasten windlass
# take windlass verify hemostasis
# ['palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'insert finger', 'incise membrane', 'drop scalpel', 'take hook', 'insert hook', 'insert hook', 'take tube', 'insert tube', 'remove hook', 'drop hook', 'detach syringe', 'drop syringe', 'drop syringe', 'drop swab', 'take swab', 'prep site', 'drop swab', 'take syringe', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'take scalpel', 'incise skin', 'incise skin', 'insert finger', 'insert finger', 'incise skin', 'incise membrane', 'drop scalpel', 'take hook', 'insert hook', 'insert hook', 'take tube', 'insert tube', 'remove hook', 'drop hook', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'incise skin', 'incise membrane', 'insert finger', 'incise membrane', 'incise membrane', 'drop scalpel', 'take hook', 'insert hook', 'insert hook', 'take tube', 'remove hook', 'remove hook', 'drop hook', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'insert finger', 'incise membrane', 'drop scalpel', 'take bougie', 'insert bougie', 'remove finger', 'take tube', 'attach tube', 'insert tube', 'remove bougie', 'drop bougie', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'insert finger', 'incise membrane', 'drop scalpel', 'take bougie', 'insert bougie', 'remove finger', 'take tube', 'attach tube', 'insert tube', 'insert tube', 'detach syringe', 'drop syringe', 'remove bougie', 'drop bougie', 'palpate landmark', 'take swab', 'prep site', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'inject lidocaine', 'drop lidocaine', 'inject lidocaine', 'inject lidocaine', 'take bougie', 'take glove', 'don glove', 'take glove', 'don glove', 'take scalpel', 'incise skin', 'incise skin', 'incise skin', 'incise skin', 'drop syringe', 'take hook', 'take tape', 'insert hook', 'insert hook', 'remove case', 'remove hook', 'drop syringe', 'drop syringe', 'insert hook', 'insert hook', 'drop ambubag', 'drop syringe', 'drop obturator', 'insert hook', 'insert hook', 'remove hook', 'drop syringe', 'attach syringe', 'attach syringe', 'attach syringe', 'attach syringe', 'attach syringe', 'attach syringe', 'attach syringe', 'drop obturator', 'drop obturator', 'drop syringe', 'take ambubag', 'detach ambubag', 'palpate landmark', 'flush catheter', 'incise skin', 'drop ambubag', 'drop ambubag', 'take tube', 'thread tape', 'thread tape', 'tie tape', 'tie tape', 'tie tape', 'drop scalpel', 'incise skin', 'incise skin', 'drop scalpel', 'take scalpel', 'incise membrane', 'identify landmark', 'take tube', 'take tube', 'insert tube', 'insert tube', 'drop obturator', 'palpate landmark', 'take scalpel', 'incise skin', 'take tube', 'take kelly', 'remove kelly', 'expand kelly', 'remove kelly', 'palpate landmark', 'take tube', 'insert tube', 'insert finger', 'remove kelly', 'expand kelly', 'remove kelly', 'insert finger', 'advance tube', 'take clamp', 'open clamp', 'apply clamp', 'close clamp', 'palpate landmark', 'incise skin', 'incise skin', 'incise skin', 'insert kelly', 'take scalpel', 'incise skin', 'take kelly', 'take kelly', 'insert kelly', 'insert kelly', 'remove kelly', 'sweep finger', 'sweep finger', 'take tube', 'insert tube', 'insert tube', 'advance tube', 'take clamp', 'take clamp', 'apply clamp', 'close clamp', 'palpate landmark', 'take scalpel', 'incise skin', 'drop scalpel', 'take kelly', 'drop kelly', 'insert kelly', 'remove kelly', 'take kelly', 'drop kelly', 'drop kelly', 'insert finger', 'drop kelly', 'take kelly', 'remove kelly', 'remove kelly', 'insert finger', 'remov ...
# ['palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'insert finger', 'incise membrane', 'drop scalpel', 'take hook', 'remove finger', 'insert hook', 'take tube', 'insert tube', 'remove hook', 'drop hook', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'palpate landmark', 'inject lidocaine', 'drop syringe', 'take scalpel', 'palpate landmark', 'incise skin', 'incise skin', 'insert finger', 'remove finger', 'incise membrane', 'insert finger', 'drop scalpel', 'take hook', 'remove finger', 'insert hook', 'take tube', 'insert tube', 'remove hook', 'drop hook', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'incise skin', 'insert finger', 'remove finger', 'incise membrane', 'insert finger', 'drop scalpel', 'take hook', 'remove finger', 'insert hook', 'take tube', 'insert tube', 'remove hook', 'drop hook', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'insert finger', 'incise membrane', 'drop scalpel', 'take bougie', 'insert bougie', 'remove finger', 'take tube', 'attach tube', 'insert tube', 'remove bougie', 'drop bougie', 'inflate cuff', 'detach syringe', 'drop syringe', 'palpate landmark', 'take swab', 'prep site', 'drop swab', 'take syringe', 'inject lidocaine', 'drop syringe', 'take scalpel', 'incise skin', 'insert finger', 'incise membrane', 'drop scalpel', 'take bougie', 'insert bougie', 'remove finger', 'take tube', 'attach tube', 'insert tube', 'inflate cuff', 'detach syringe', 'drop syringe', 'remove bougie', 'drop bougie', 'palpate landmark', 'take swab', 'prep site', 'prep site', 'drop swab', 'take syringe', 'take lidocaine', 'withdraw lidocaine', 'drop lidocaine', 'inject lidocaine', 'inject lidocaine', 'drop syringe', 'take glove', 'don glove', 'take glove', 'don glove', 'take scalpel', 'palpate landmark', 'incise skin', 'incise skin', 'incise skin', 'drop scalpel', 'take hook', 'take tube', 'insert hook', 'insert tube', 'remove tube', 'remove hook', 'drop hook', 'drop tube', 'insert finger', 'sweep finger', 'remove finger', 'take hook', 'take tube', 'insert hook', 'insert tube', 'remove hook', 'drop hook', 'take syringe', 'attach syringe', 'inflate cuff', 'detach syringe', 'attach syringe', 'inflate cuff', 'detach syringe', 'drop syringe', 'remove obturator', 'drop obturator', 'take ambubag', 'attach ambubag', 'compress ambubag', 'compress ambubag', 'compress ambubag', 'detach ambubag', 'drop ambubag', 'take tape', 'thread tape', 'thread tape', 'tie tape', 'secure tube', 'tie tape', 'palpate landmark', 'incise skin', 'incise skin', 'drop scalpel', 'take scalpel', 'incise membrane', 'drop scalpel', 'take tube', 'insert tube', 'insert tube', 'remove obturator', 'drop obturator', 'palpate landmark', 'take scalpel', 'incise skin', 'drop scalpel', 'take kelly', 'palpate landmark', 'insert kelly', 'expand kelly', 'remove kelly', 'take tube', 'attach kelly and tube', 'insert finger', 'remove finger', 'insert kelly/tube', 'detach kelly', 'remove kelly', 'drop kelly', 'take clamp', 'open clamp', 'apply clamp', 'close clamp', 'palpate landmark', 'take scalpel', 'incise skin', 'drop scalpel', 'palpate landmark', 'take scalpel', 'incise skin', 'drop scalpel', 'take kelly', 'insert kelly', 'expand kelly', 'remove kelly', 'insert finger', 'sweep finger', 'take tube', 'insert tube', 'advance tube', 'remove finger', 'take clamp', 'open clamp', 'apply clamp', 'close clamp', 'palpate landmark', 'take scalpel', 'incise skin', 'drop scalpel', 'take kelly', 'palpate landmark', 'insert kelly', 'expand kelly', 'remove kelly', 'drop kelly', 'insert finger', 'sweep finger', 'take kelly', 'take ...

# %%
correct = 0
total = 0
for i in range(len(generated_answers)):
    if((generated_answers[i])==(labels[i])):
        correct = correct+1
        print(correct, total)
    total = total+1
print(correct/total)
# Out:
# 1 0
# 2 1
# 3 2
# 4 3
# 5 4
# 6 5
# 7 6
# 8 7
# 9 8
# 10 9
# 11 10
# 12 11
# 13 12
# 14 14
# 15 15
# 16 16
# 17 17
# 18 18
# 19 21
# 20 23
# 21 24
# 22 25
# 23 26
# 24 28
# 25 29
# 26 30
# 27 32
# 28 33
# 29 34
# 30 38
# 31 39
# 32 41
# 33 42
# 34 43
# 35 44
# 36 45
# 37 46
# 38 47
# 39 48
# 40 49
# 41 50
# 42 51
# 43 52
# 44 53
# 45 54
# 46 55
# 47 56
# 48 57
# 49 58
# 50 61
# 51 63
# 52 64
# 53 66
# 54 67
# 55 69
# 56 70
# 57 71
# 58 72
# 59 73
# 60 74
# 61 75
# 62 76
# 63 77
# 64 78
# 65 79
# 66 80
# 67 81
# 68 82
# 69 83
# 70 84
# 71 85
# 72 86
# 73 87
# 74 88
# 75 89
# 76 90
# 77 91
# 78 92
# 79 93
# 80 94
# 81 95
# 82 96
# 83 97
# 84 98
# 85 99
# 86 100
# 87 101
# 88 102
# 89 103
# 90 104
# 91 105
# 92 106
# 93 107
# 94 108
# 95 109
# 96 110
# 97 111
# 98 112
# 99 113
# 100 114
# 101 116
# 102 117
# 103 118
# 104 119
# 105 120
# 106 121
# 107 122
# 108 123
# 109 124
# 110 125
# 111 128
# 112 129
# 113 130
# 114 132
# 115 133
# 116 134
# 117 135
# 118 136
# 119 138
# 120 139
# 121 140
# 122 142
# 123 144
# 124 147
# 125 155
# 126 157
# 127 160
# 128 163
# 129 169
# 130 175
# 131 177
# 132 178
# 133 179
# 134 181
# 135 183
# 136 184
# 137 185
# 138 186
# 139 187
# 140 189
# 141 191
# 142 193
# 143 194
# 144 195
# 145 196
# 146 198
# 147 203
# 148 205
# 149 211
# 150 212
# 151 213
# 152 214
# 153 215
# 154 217
# 155 220
# 156 221
# 157 223
# 158 224
# 159 226
# 160 228
# 161 229
# 162 230
# 163 233
# 164 235
# 165 236
# 166 237
# 167 238
# 168 239
# 169 240
# 170 241
# 171 243
# 172 246
# 173 257
# 174 259
# 175 260
# 176 261
# 177 262
# 178 263
# 179 264
# 180 265
# 181 267
# 182 268
# 183 270
# 184 272
# 185 273
# 186 275
# 187 276
# 188 278
# 189 282
# 190 285
# 191 287
# 192 288
# 193 289
# 194 290
# 195 291
# 196 293
# 197 294
# 198 295
# 199 296
# 200 299
# 201 300
# 202 301
# 203 302
# 204 304
# 205 306
# 206 313
# 207 330
# 208 336
# 209 337
# 210 341
# 211 344
# 212 345
# 213 347
# 214 348
# 215 349
# 216 350
# 217 351
# 218 352
# 219 353
# 220 364
# 221 371
# 222 373
# 223 376
# 224 377
# 225 378
# 226 379
# 227 380
# 228 382
# 229 383
# 230 385
# 231 390
# 232 391
# 233 393
# 234 399
# 235 404
# 236 407
# 237 408
# 238 409
# 239 410
# 240 411
# 241 412
# 242 413
# 243 414
# 244 416
# 245 417
# 246 418
# 247 419
# 248 420
# 249 421
# 250 422
# 251 423
# 252 424
# 253 425
# 254 426
# 255 427
# 256 429
# 257 430
# 258 431
# 259 432
# 260 433
# 261 434
# 262 435
# 263 436
# 264 438
# 265 439
# 266 440
# 267 441
# 268 442
# 269 445
# 270 446
# 271 447
# 272 448
# 273 450
# 274 452
# 275 453
# 276 454
# 277 455
# 278 456
# 279 458
# 280 459
# 281 461
# 282 462
# 283 463
# 284 464
# 285 467
# 286 469
# 287 471
# 288 473
# 289 474
# 290 476
# 291 477
# 292 478
# 293 479
# 294 480
# 295 481
# 296 482
# 297 483
# 298 484
# 299 485
# 300 486
# 301 487
# 302 488
# 303 489
# 304 490
# 305 491
# 306 493
# 307 494
# 308 495
# 309 496
# 310 497
# 311 498
# 312 500
# 313 501
# 314 503
# 315 505
# 316 507
# 317 509
# 318 510
# 319 511
# 320 512
# 321 519
# 322 522
# 323 523
# 324 524
# 325 525
# 326 527
# 327 528
# 328 529
# 329 530
# 330 532
# 331 533
# 332 534
# 333 536
# 334 537
# 335 539
# 336 540
# 337 541
# 338 542
# 339 543
# 340 544
# 341 545
# 342 546
# 343 547
# 344 548
# 345 549
# 346 550
# 347 551
# 348 552
# 349 553
# 350 554
# 351 555
# 352 556
# 353 557
# 354 558
# 355 559
# 356 560
# 357 561
# 358 566
# 359 567
# 360 568
# 361 569
# 362 570
# 363 571
# 364 572
# 365 574
# 366 575
# 367 576
# 368 577
# 369 578
# 370 579
# 371 581
# 372 582
# 373 583
# 374 584
# 375 585
# 376 586
# 377 587
# 378 588
# 379 589
# 380 590
# 381 591
# 382 592
# 383 593
# 384 594
# 385 595
# 386 596
# 387 597
# 388 600
# 389 601
# 390 602
# 391 603
# 392 604
# 393 605
# 394 607
# 395 609
# 396 613
# 397 614
# 398 617
# 399 618
# 400 620
# 401 621
# 402 622
# 403 623
# 404 624
# 405 625
# 406 626
# 407 627
# 408 628
# 409 629
# 410 630
# 411 631
# 412 632
# 413 634
# 414 635
# 415 636
# 416 637
# 417 639
# 418 641
# 419 642
# 420 645
# 421 647
# 422 648
# 423 649
# 424 651
# 425 652
# 426 653
# 427 654
# 428 655
# 429 656
# 430 657
# 431 658
# 432 659
# 433 660
# 434 661
# 435 662
# 436 663
# 437 664
# 438 665
# 439 666
# 440 667
# 441 668
# 442 671
# 443 672
# 444 673
# 445 674
# 446 675
# 447 677
# 448 679
# 449 680
# 0.657393850658858
